# %%
import sys
print(sys.executable)
print(sys.path[0])
# Out:
# /home/cluster-dgxa100/slp03/whisper/whisper_multitaskB/.whisperB/bin/python3
# /usr/lib/python312.zip

# %%
import os
os.getcwd()
# Out:
# '/home/cluster-dgxa100/slp03/whisper/whisper_multitaskB'

# %%
# %cd scripts
# Out:
# /home/cluster-dgxa100/slp03/whisper/whisper_multitaskB/scripts

# %%
# %run train_disease.py --model_size tiny --epochs 50
# Out:
# Multi-task Training Configuration:
#   Model: Whisper-tiny
#   Mode: multi_task
#   Device: cuda
#   Batch sizes: Train=16, Val=8
#   Loss weights: α=0.0, β=0.0
#   Audio: librosa (sr=16000, n_mels=80)
#   Save directory: ../checkpoints_weightA/checkpoints_tiny
#   Disease tokens: ['normal', 'dysarthria', 'dysphonia']
#
# === Multi-Task Learning Configuration ===
# Model: Whisper-tiny
# Device: cuda
# Batch sizes: Train=16, Val=8
# Epochs: 50
# Learning rate: 1e-05
# Freeze encoder: True
# Audio processing: librosa
#
# Loading datasets...
# Multi-task Dataset loaded: 1737 samples
# EOT token: 50257
# Disease tokens available: ['normal', 'dysarthria', 'dysphonia']
# Class distribution:
#   normal: 579 samples (33.3%)
#   dysarthria: 579 samples (33.3%)
#   dysphonia: 579 samples (33.3%)
# Multi-task Dataset loaded: 213 samples
# EOT token: 50257
# Disease tokens available: ['normal', 'dysarthria', 'dysphonia']
# Class distribution:
#   normal: 71 samples (33.3%)
# ...

# %%
# %run inference_disease.py --model_path ../checkpoints_weightA/checkpoints_tiny/best_multitask_model_tiny.pt --save_results inference_results.csv
# Out:
# === MULTI-TASK MODEL COMPREHENSIVE INFERENCE ===
# Model: ../checkpoints_weightA/checkpoints_tiny/best_multitask_model_tiny.pt
# Test data: /home/cluster-dgxa100/slp03/whisper/whisper_multitaskB/data/custom_test.csv
# Device: cuda
# Loading trained model...
# === Multi-Task Learning Trainer ===
# Device: cuda
# CUDA device: NVIDIA A100-SXM4-40GB
# CUDA memory: 42.4 GB
# ✔ Whisper model loaded on cuda
# ✔ Tokenizer loaded with disease support
#   EOT token: 50257
#   SOT token: 50258
#   Language token: 50259
#   Transcribe token: 50363
#   Disease tokens: ['normal', 'dysarthria', 'dysphonia']
# Vocabulary sizes: Original=51865, New=51869
# Expanding vocabulary: 51865 -> 51869
# Resized embedding layer device: cuda:0
# ✔ Vocabulary expanded
# ✔ Disease classifier created on cuda
# ✔ Encoder frozen
# ✔ New embeddings added to training: 4 tokens
# Trainable parameters: 29,629,827
# ✔ Trainer initialized successfully
# ✔ Best loss weights loaded: α=0.2183, β=0.7817
# ...
