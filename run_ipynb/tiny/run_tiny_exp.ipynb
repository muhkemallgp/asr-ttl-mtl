# %%
import sys
print(sys.executable)
print(sys.path[0])
# Out:
# /home/is/lathifgalih-k/research_naist/.venv/bin/python
# /usr/lib/python310.zip

# %%
import os
os.getcwd()
# Out:
# '/home/is/lathifgalih-k/research_naist/run_ipynb/tiny'

# %%
# %cd ../../scripts
# Out:
# /home/is/lathifgalih-k/research_naist/scripts
# /home/is/lathifgalih-k/research_naist/.venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %run train_disease.py --model_size tiny --epochs 50 --save_dir ../checkpoints_exp/checkpoints_tiny/
# Out:
# Multi-task Training Configuration:
#   Model: Whisper-tiny
#   Mode: multi_task
#   Device: cuda
#   Batch sizes: Train=16, Val=8
#   Loss weights: α=0.0, β=0.0
#   Audio: librosa (sr=16000, n_mels=80)
#   Save directory: ../checkpoints_exp/checkpoints_tiny/
#   Disease tokens: ['normal', 'dysarthria', 'dysphonia']
#
# === Multi-Task Learning Configuration ===
# Model: Whisper-tiny
# Device: cuda
# Batch sizes: Train=16, Val=8
# Epochs: 50
# Learning rate: 1e-05
# Freeze encoder: True
# Audio processing: librosa
#
# Loading datasets...
# Multi-task Dataset loaded: 1737 samples
# Model type: Multilingual
# EOT token: 50257
# SOT token: 50258
# Disease tokens available: ['normal', 'dysarthria', 'dysphonia']
# Class distribution:
#   normal: 579 samples (33.3%)
#   dysphonia: 579 samples (33.3%)
#   dysarthria: 579 samples (33.3%)
# Multi-task Dataset loaded: 213 samples
# Model type: Multilingual
# EOT token: 50257
# SOT token: 50258
# ...

# %%
# %run inference_disease.py --model_path ../checkpoints_exp/checkpoints_tiny/best_multitask_model_tiny.pt --save_results ../checkpoints_exp/checkpoints_tiny/inference_results.csv
# Out:
# === MULTI-TASK MODEL COMPREHENSIVE INFERENCE ===
# Model: ../checkpoints_exp/checkpoints_tiny/best_multitask_model_tiny.pt
# Test data: /home/is/lathifgalih-k/research_naist/data/custom_test.csv
# Device: cuda
# Loading trained model...
# === Multi-Task Learning Trainer ===
# Device: cuda
# CUDA device: NVIDIA H100 NVL
# CUDA memory: 100.0 GB
# ✔ Whisper model loaded on cuda
# ✔ Tokenizer loaded with disease support
#   EOT token: 50257
#   SOT token: 50258
#   Language token: 50259
#   Transcribe token: 50363
#   Disease tokens: ['normal', 'dysarthria', 'dysphonia']
# Vocabulary sizes: Original=51865, New=51869
# Expanding vocabulary: 51865 -> 51869
# Resized embedding layer device: cuda:0
# ✔ Vocabulary expanded
# ✔ Disease classifier created on cuda
# ✔ Encoder frozen
# ✔ New embeddings added to training: 4 tokens
# Trainable parameters: 29,629,827
# ✔ Trainer initialized successfully
# ✔ Best loss weights loaded: α=0.2402, β=0.7598
# ...
