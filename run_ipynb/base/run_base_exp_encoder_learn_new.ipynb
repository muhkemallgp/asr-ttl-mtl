# %%
import sys
print(sys.executable)
print(sys.path[0])
# Out:
# /home/is/lathifgalih-k/research_naist/ast-tts/.mtl-venv/bin/python3
# /usr/lib/python310.zip

# %%
import os
os.getcwd()
# Out:
# '/home/is/lathifgalih-k/research_naist/ast-tts/run_ipynb/base'

# %%
# %cd ../../scripts
# Out:
# /home/is/lathifgalih-k/research_naist/ast-tts/scripts
# /home/is/lathifgalih-k/research_naist/ast-tts/.mtl-venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import os
os.getcwd()
# Out:
# '/home/is/lathifgalih-k/research_naist/ast-tts/scripts'

# %%
import pandas as pd
df = pd.read_csv("/home/is/lathifgalih-k/research_naist/ast-tts/checkpoints_exp/checkpoints_base.en_encoder_learning_new/inference_results.csv")
df
# Out:
#                                           file_path  \
# 0           ../DATASET/torgo/FC01/Session1/0054.wav
# 1           ../DATASET/torgo/MC02/Session2/0055.wav
# 2    ../DATASET/uncommonvoice/FC45_T2_si1014_NA.wav
# 3           ../DATASET/torgo/MC03/Session2/0170.wav
# 4    ../DATASET/uncommonvoice/FC45_T2_si1969_NA.wav
# ..                                              ...
# 202          ../DATASET/torgo/M04/Session2/0156.wav
# 203          ../DATASET/torgo/F04/Session2/0248.wav
# 204          ../DATASET/torgo/F03/Session3/0044.wav
# 205          ../DATASET/torgo/F03/Session1/0135.wav
# 206          ../DATASET/torgo/F03/Session1/0121.wav
#
#                                          original_text  \
# 0         You wished to know all about my grandfather.
# 1    He really crucified him; he nailed it for a ya...
# 2    beer generally fermented from barley is an old...
# 3    We experience distress and frustration obtaini...
# 4        if any of us miss they can pick up the pieces
# ...

# %%
# %run train_disease.py --model_size base --epochs 50 --save_dir ../checkpoints_exp/checkpoints_base_encoder_learning_new/
# Out:
# Multi-task Training Configuration:
#   Model: Whisper-base
#   Mode: multi_task
#   Device: cuda
#   Batch sizes: Train=16, Val=8
#   Loss weights: α=0.0, β=0.0
#   Audio: librosa (sr=16000, n_mels=80)
#   Save directory: ../checkpoints_exp/checkpoints_base_encoder_learning_new/
#   Disease tokens: ['normal', 'dysphonia', 'dysarthria']
#
# === Multi-Task Learning Configuration ===
# Model: Whisper-base
# Device: cuda
# Batch sizes: Train=16, Val=8
# Epochs: 50
# Learning rate: 1e-05
# Freeze encoder: False
# Audio processing: librosa
#
# Loading datasets...
# Multi-task Dataset loaded: 1737 samples
# Model type: Multilingual
# EOT token: 50257
# SOT token: 50258
# Disease tokens available: ['normal', 'dysarthria', 'dysphonia']
# Class distribution:
#   normal/0: 579 samples (33.3%)
#   dysphonia/1: 579 samples (33.3%)
#   dysarthria/2: 579 samples (33.3%)
# Multi-task Dataset loaded: 213 samples
# Model type: Multilingual
# EOT token: 50257
# SOT token: 50258
# ...

# %%
# %run inference_disease.py --model_path ../checkpoints_exp/checkpoints_base_encoder_learning_new/best_multitask_model_base.pt --save_results ../checkpoints_exp/checkpoints_base_encoder_learning_new/inference_results.csv
# Out:
# === MULTI-TASK MODEL COMPREHENSIVE INFERENCE ===
# Model: ../checkpoints_exp/checkpoints_base_encoder_learning_new/best_multitask_model_base.pt
# Test data: /home/is/lathifgalih-k/research_naist/ast-tts/data/custom_test.csv
# Device: cuda
# Loading trained model...
# === Multi-Task Learning Trainer ===
# Device: cuda
# CUDA device: NVIDIA GeForce RTX 3090
# CUDA memory: 25.3 GB
# ✔ Whisper model loaded on cuda
# ✔ Tokenizer loaded with disease support
#   EOT token: 50257
#   SOT token: 50258
#   Language token: 50259
#   Transcribe token: 50363
#   Disease tokens: ['normal', 'dysarthria', 'dysphonia']
# Vocabulary sizes: Original=51865, New=51869
# Expanding vocabulary: 51865 -> 51869
# Resized embedding layer device: cuda:0
# ✔ Vocabulary expanded
# ✔ Disease classifier created on cuda
# Encoder is trainable
# ✔ New embeddings added to training: 4 tokens
# Trainable parameters: 52,139,523
# ✔ Encoder parameters added to training: 19,822,592
# ✔ Trainer initialized successfully
# ...
